# %% [markdown]
# # Data Preprocessing

# %% [markdown]
# ## Importing the Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# ## Reading the Dataset

# %%
data = pd.read_csv('Data Set/Admission_Predict.csv')

# %%
data.head()
# Out:
#    Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# 0           1        337          118                  4  4.5   4.5  9.65
# 1           2        324          107                  4  4.0   4.5  8.87
# 2           3        316          104                  3  3.0   3.5  8.00
# 3           4        322          110                  3  3.5   2.5  8.67
# 4           5        314          103                  2  2.0   3.0  8.21
#
#    Research  Chance of Admit
# 0         1              0.92
# 1         1              0.76
# 2         1              0.72
# 3         1              0.80
# 4         0              0.65

# %%
data.tail()
# Out:
#      Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# 395         396        324          110                  3  3.5   3.5  9.04
# 396         397        325          107                  3  3.0   3.5  9.11
# 397         398        330          116                  4  5.0   4.5  9.45
# 398         399        312          103                  3  3.5   4.0  8.78
# 399         400        333          117                  4  5.0   4.0  9.66
#
#      Research  Chance of Admit
# 395         1              0.82
# 396         1              0.84
# 397         1              0.91
# 398         0              0.67
# 399         1              0.95

# %%
print(f'No of Rows in the dataset : {data.shape[0]}')
print(f'No of Columns in the dataset : {data.shape[1]}')
# Out:
# No of Rows in the dataset : 400
# No of Columns in the dataset : 9

# %% [markdown]
# ## Descriptive Statistics

# %%
data.describe()
# Out:
#        Serial No.   GRE Score  TOEFL Score  University Rating         SOP  \
# count  400.000000  400.000000   400.000000         400.000000  400.000000
# mean   200.500000  316.807500   107.410000           3.087500    3.400000
# std    115.614301   11.473646     6.069514           1.143728    1.006869
# min      1.000000  290.000000    92.000000           1.000000    1.000000
# 25%    100.750000  308.000000   103.000000           2.000000    2.500000
# 50%    200.500000  317.000000   107.000000           3.000000    3.500000
# 75%    300.250000  325.000000   112.000000           4.000000    4.000000
# max    400.000000  340.000000   120.000000           5.000000    5.000000
#
#              LOR         CGPA    Research  Chance of Admit
# count  400.000000  400.000000  400.000000        400.000000
# mean     3.452500    8.598925    0.547500          0.724350
# std      0.898478    0.596317    0.498362          0.142609
# min      1.000000    6.800000    0.000000          0.340000
# 25%      3.000000    8.170000    0.000000          0.640000
# 50%      3.500000    8.610000    1.000000          0.730000
# 75%      4.000000    9.062500    1.000000          0.830000
# max      5.000000    9.920000    1.000000          0.970000

# %%
data.skew()
# Out:
# Serial No.           0.000000
# GRE Score           -0.062893
# TOEFL Score          0.057216
# University Rating    0.171260
# SOP                 -0.275761
# LOR                 -0.106991
# CGPA                -0.065991
# Research            -0.191582
# Chance of Admit     -0.353448
# dtype: float64

# %% [markdown]
# ## Handling Missing Values

# %%
# Remove unwanted feature
data.drop('Serial No.', inplace=True, axis=1)

# %%
data.columns
# Out:
# Index(['GRE Score', 'TOEFL Score', 'University Rating', 'SOP', 'LOR ', 'CGPA',
#        'Research', 'Chance of Admit '],
#       dtype='object')

# %%
#rename the column
data = data.rename(columns={'LOR ':'LOR','Chance of Admit ':'Chance of Admit'})

# %%
data.columns
# Out:
# Index(['GRE Score', 'TOEFL Score', 'University Rating', 'SOP', 'LOR', 'CGPA',
#        'Research', 'Chance of Admit'],
#       dtype='object')

# %%
data.isnull().sum()
# Out:
# GRE Score            0
# TOEFL Score          0
# University Rating    0
# SOP                  0
# LOR                  0
# CGPA                 0
# Research             0
# Chance of Admit      0
# dtype: int64

# %% [markdown]
# *The Dataset does not have any null values*

# %% [markdown]
# ## Check for Categorical columns

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   GRE Score          400 non-null    int64
#  1   TOEFL Score        400 non-null    int64
#  2   University Rating  400 non-null    int64
#  3   SOP                400 non-null    float64
#  4   LOR                400 non-null    float64
#  5   CGPA               400 non-null    float64
#  6   Research           400 non-null    int64
#  7   Chance of Admit    400 non-null    float64
# dtypes: float64(4), int64(4)
# memory usage: 25.1 KB

# %%
data.dtypes
# Out:
# GRE Score              int64
# TOEFL Score            int64
# University Rating      int64
# SOP                  float64
# LOR                  float64
# CGPA                 float64
# Research               int64
# Chance of Admit      float64
# dtype: object

# %% [markdown]
# *Data looks pretty clean and in the right data type format.*

# %% [markdown]
# ## Data Visualization

# %% [markdown]
# ### Univariate Analysis

# %%
sns.displot(x=data["GRE Score"], kde=True, color='green')
plt.title("GRE score distribution");

# %% [markdown]
# Observations for GRE Score :
# - Score is distributed in the range of 290 to 340.
# - Peaks are observed between 310 to 330 indicating most applicants have scored in this range.

# %%
sns.displot(x=data["TOEFL Score"], kde=True, color='purple')
plt.title("TOEFL score distribution");

# %% [markdown]
# Observations from TOFEL Score :
# - TOFEL scores are distributed in the range of 90 to 120.
# - A good number of applicants have scored in between 100 to 115.

# %%
sns.countplot(x=data["University Rating"]);
plt.title("Number of Universities for each star rating by applicants");

# %% [markdown]
# Observations on University rating :
# - Close to 130 applicants have marked their university as 3 stars.
# - 3 stars are followed by 2 stars for universities.
# - 1 star is given by only 30 applicants which is lowest.

# %%
sns.displot(x=data["SOP"], kde=True, color='green');
plt.title("Distribution for ratings on SOP");

# %% [markdown]
# Observations from statement of purpose :
# - Most of the applicants have received 3.0 to 4.0 stars in their SOP.
# - Based on the plot, rating distribution can be bucketed in 3 sections 1.0 to 2.6 as low ratings and 3.0 to 5.0 as high level of ratings.

# %%
sns.displot(x=data["LOR"], kde=True, color='purple');
plt.title("Letter of recommendation of applicants Distribution");

# %% [markdown]
# Observations for LOR :
# - Most applicants have a recommendation ratting of 3.0.
# - A very good number of applicants are having LOR ratting between 3 to 4 inclusive.

# %%
sns.displot(x=data["CGPA"], kde=True, color='green');
plt.title("Distribution of CGPA Score");

# %% [markdown]
# Observations for CGPA :
# - CGPA scores are distributed in range of 6.8 to 9.92 inclusive.
# - More than 70 applicants have the CGPA of 8.67.

# %%
sns.countplot(x=data["Research"]);
plt.title("Research Count");

# %% [markdown]
# Observations on Research :
# - Out of 400 applicants approx 240 applicants have opened for research.
# - In precentage 64% applicants are chosing for research option.

# %% [markdown]
# ### Bivariate Analysis

# %%
cols = data.columns

# %%
features = [i for i in data.columns if i != 'Chance of Admit']
label = 'Chance of Admit'

# %%
features
# Out:
# ['GRE Score',
#  'TOEFL Score',
#  'University Rating',
#  'SOP',
#  'LOR',
#  'CGPA',
#  'Research']

# %%
plt.figure(figsize=(15, 12))
for i in range(len(features)):
    plt.subplot(4, 2, i+1)
    sns.lineplot(x=features[i], y=label, data=data, color='purple')
plt.tight_layout()   
plt.plot()
# Out:
# []

# %%
plt.figure(figsize=(15, 12))
for i in range(len(features)):
    plt.subplot(4, 2, i+1)
    sns.scatterplot(x=features[i], y=label, data=data, color='purple')
plt.tight_layout()   
plt.plot()
# Out:
# []

# %%
plt.figure(figsize=(15, 12))
for i in range(len(features)):
    plt.subplot(4, 2, i+1)
    sns.boxplot(x=data[features[i]])
plt.tight_layout()

# %% [markdown]
# Observations based on above box plot :
# - The outlier observed in boxplot is basically just one applicant having
#     - the lowest LOR rating of 1.
#     - the lowest CGPA score is 6.8

# %% [markdown]
# ### Multi-Variate Analysis

# %%
sns.pairplot(data,hue='Research')

# %%
corr_matrix = data.corr()
plt.figure(figsize = (15, 15))
sns.heatmap(corr_matrix,annot=True,fmt='0.2f')
plt.title("Correlation Matrix", fontsize = 20)
plt.show()

# %% [markdown]
# ## Split the data into dependent and independent variables

# %%
data.head()
# Out:
#    GRE Score  TOEFL Score  University Rating  SOP  LOR  CGPA  Research  \
# 0        337          118                  4  4.5  4.5  9.65         1
# 1        324          107                  4  4.0  4.5  8.87         1
# 2        316          104                  3  3.0  3.5  8.00         1
# 3        322          110                  3  3.5  2.5  8.67         1
# 4        314          103                  2  2.0  3.0  8.21         0
#
#    Chance of Admit
# 0             0.92
# 1             0.76
# 2             0.72
# 3             0.80
# 4             0.65

# %%
x = data.iloc[:,0:7]
y = data['Chance of Admit']

# %%
x.head()
# Out:
#    GRE Score  TOEFL Score  University Rating  SOP  LOR  CGPA  Research
# 0        337          118                  4  4.5  4.5  9.65         1
# 1        324          107                  4  4.0  4.5  8.87         1
# 2        316          104                  3  3.0  3.5  8.00         1
# 3        322          110                  3  3.5  2.5  8.67         1
# 4        314          103                  2  2.0  3.0  8.21         0

# %%
y.head().to_frame()
# Out:
#    Chance of Admit
# 0             0.92
# 1             0.76
# 2             0.72
# 3             0.80
# 4             0.65

# %%
print(f'x contains: {x.shape[0]} rows and {x.shape[1]} columns')
# Out:
# x contains: 400 rows and 7 columns

# %%
print(f'y contains: {y.shape}')
# Out:
# y contains: (400,)

# %% [markdown]
# ## Scale the independent variables

# %%
from sklearn.preprocessing import MinMaxScaler
scaler=MinMaxScaler()

# %%
x[x.columns] = scaler.fit_transform(x[x.columns])

# %%
x.head()
# Out:
#    GRE Score  TOEFL Score  University Rating    SOP    LOR      CGPA  Research
# 0       0.94     0.928571               0.75  0.875  0.875  0.913462       1.0
# 1       0.68     0.535714               0.75  0.750  0.875  0.663462       1.0
# 2       0.52     0.428571               0.50  0.500  0.625  0.384615       1.0
# 3       0.64     0.642857               0.50  0.625  0.375  0.599359       1.0
# 4       0.48     0.392857               0.25  0.250  0.500  0.451923       0.0

# %% [markdown]
# ## Split the data into training and testing

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size=0.2, random_state=42)

# %%
print(f'x_train contains: {x_train.shape[0]} rows and {x_train.shape[1]} columns')
print(f'x_test contains: {x_test.shape[0]} rows and {x_test.shape[1]} columns')
# Out:
# x_train contains: 320 rows and 7 columns
# x_test contains: 80 rows and 7 columns

# %%
print(f'y_train contains: {y_train.shape}')
print(f'y_test contains: {y_test.shape}')
# Out:
# y_train contains: (320,)
# y_test contains: (80,)

# %%
y_train_target = [1 if each > 0.8 else 0 for each in y_train]
y_test_target = [1 if each > 0.8 else 0 for each in y_test]

# %% [markdown]
# To convert this test label of probability as either 1 or 0
# - 1 means Yes
# - 0 means No

# %% [markdown]
# # Model Building

# %% [markdown]
# ##  Training And Testing The Model

# %% [markdown]
# **Linear Regression**

# %%
from sklearn.linear_model import LinearRegression

lr = LinearRegression()
lr.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
lr_pred = lr.predict(x_test)

# %%
lr_pred
# Out:
# array([0.65117446, 0.72368741, 0.93536809, 0.82164316, 0.58158673,
#        0.92863016, 0.52682366, 0.54308993, 0.65940583, 0.83834924,
#        0.72008833, 0.90749769, 0.55354476, 0.89008648, 0.70389539,
#        0.68664473, 0.66657268, 0.48196096, 0.69057217, 0.97493132,
#        0.58802433, 0.65286881, 0.71150098, 0.53528647, 0.94677007,
#        0.80982947, 0.69459383, 0.56495613, 0.68192423, 0.81039878,
#        0.80796481, 0.94640983, 0.64599494, 0.51104918, 0.65983663,
#        0.66907811, 0.71572271, 0.64556878, 0.61540702, 0.87367833,
#        0.74275261, 0.59782649, 0.77456683, 0.95944897, 0.85124125,
#        0.83554825, 0.94662422, 0.64822919, 0.92247594, 0.85906183,
#        0.89624998, 0.72869743, 0.78874783, 0.95142703, 0.57325803,
#        0.58744723, 0.68621316, 0.84544646, 0.60495144, 0.84808919,
#        0.66642894, 0.65524969, 0.70024808, 0.51206905, 0.62930376,
#        0.7173701 , 0.62200838, 0.84170334, 0.85675802, 0.79886217,
#        0.72196478, 0.81448203, 0.87373609, 0.83332085, 0.52554247,
#        0.72181818, 0.6896438 , 0.59442609, 0.87840579, 0.75779333])

# %% [markdown]
# **Decision Tree**

# %%
from sklearn.tree import DecisionTreeRegressor

DT = DecisionTreeRegressor()
DT.fit(x_train, y_train)
# Out:
# DecisionTreeRegressor()

# %%
DT_predict = DT.predict(x_test)

# %%
DT_predict
# Out:
# array([0.62, 0.73, 0.93, 0.81, 0.59, 0.91, 0.59, 0.38, 0.65, 0.91, 0.79,
#        0.93, 0.49, 0.91, 0.76, 0.75, 0.71, 0.44, 0.67, 0.97, 0.62, 0.67,
#        0.66, 0.56, 0.95, 0.84, 0.7 , 0.67, 0.69, 0.76, 0.76, 0.94, 0.48,
#        0.44, 0.72, 0.67, 0.71, 0.79, 0.73, 0.92, 0.76, 0.65, 0.78, 0.94,
#        0.88, 0.84, 0.97, 0.64, 0.94, 0.88, 0.93, 0.74, 0.8 , 0.95, 0.58,
#        0.68, 0.72, 0.83, 0.59, 0.88, 0.64, 0.62, 0.63, 0.47, 0.73, 0.52,
#        0.64, 0.89, 0.88, 0.85, 0.75, 0.84, 0.93, 0.9 , 0.54, 0.76, 0.77,
#        0.53, 0.89, 0.85])

# %% [markdown]
# **Random Forest Regressor**

# %%
from sklearn.ensemble import RandomForestRegressor

rf = RandomForestRegressor()
rf.fit(x_train,y_train)
# Out:
# RandomForestRegressor()

# %%
rf_predict = rf.predict(x_test)

# %%
rf_predict
# Out:
# array([0.6606, 0.7186, 0.9364, 0.8117, 0.566 , 0.9153, 0.5715, 0.476 ,
#        0.6713, 0.8951, 0.7183, 0.9394, 0.5427, 0.9002, 0.7153, 0.6568,
#        0.6943, 0.4842, 0.7094, 0.96  , 0.6137, 0.6897, 0.6942, 0.5419,
#        0.9423, 0.8162, 0.7266, 0.5711, 0.7094, 0.7897, 0.794 , 0.9421,
#        0.6599, 0.4636, 0.7102, 0.6699, 0.6828, 0.6941, 0.6362, 0.9265,
#        0.7593, 0.645 , 0.7695, 0.9447, 0.8774, 0.8405, 0.963 , 0.6518,
#        0.9286, 0.8874, 0.9068, 0.7022, 0.7621, 0.9435, 0.5767, 0.5843,
#        0.6885, 0.8425, 0.5771, 0.8654, 0.6448, 0.6411, 0.6826, 0.4501,
#        0.6813, 0.6356, 0.6187, 0.8438, 0.8801, 0.7642, 0.6666, 0.8136,
#        0.9207, 0.8706, 0.5265, 0.7369, 0.6791, 0.5295, 0.8369, 0.7654])

# %% [markdown]
# **Gradient Boosting Regressor**

# %%
from sklearn.ensemble import GradientBoostingRegressor
gbr = GradientBoostingRegressor(n_estimators=100)
gbr.fit(x_train, y_train)
# Out:
# GradientBoostingRegressor()

# %%
gbrpredict = gbr.predict(x_test)

# %%
gbrpredict
# Out:
# array([0.66617022, 0.7358382 , 0.93809924, 0.82159856, 0.58411603,
#        0.93120349, 0.57354882, 0.44805532, 0.62798229, 0.8758663 ,
#        0.73375561, 0.93685918, 0.52355634, 0.91246253, 0.71011182,
#        0.67670276, 0.67098904, 0.49838166, 0.70939002, 0.96062563,
#        0.6201632 , 0.68761759, 0.7402906 , 0.5455057 , 0.93875236,
#        0.78676595, 0.70316376, 0.52738259, 0.69373922, 0.78182102,
#        0.79666902, 0.94375578, 0.66233014, 0.43289662, 0.69138894,
#        0.64997028, 0.7049326 , 0.6960291 , 0.61495043, 0.89060994,
#        0.75206863, 0.66758976, 0.75896315, 0.94891703, 0.88058616,
#        0.84756846, 0.95280263, 0.66257266, 0.91824565, 0.88644318,
#        0.90313322, 0.72897905, 0.78541446, 0.9406663 , 0.57598611,
#        0.57394981, 0.69068383, 0.85663026, 0.58710586, 0.8793323 ,
#        0.6564905 , 0.66108942, 0.67231634, 0.49861991, 0.66558671,
#        0.67520907, 0.58385253, 0.79739796, 0.87680956, 0.76534338,
#        0.70057813, 0.79915312, 0.90561192, 0.86383986, 0.54779793,
#        0.71951244, 0.69614962, 0.50810872, 0.84971004, 0.76249915])

# %% [markdown]
# **Xg boost**

# %%
pip install xgboost
# Out:
# Collecting xgboost
#   Downloading xgboost-1.7.1-py3-none-manylinux2014_x86_64.whl (193.6 MB)
#      |████████████████████▉           | 126.1 MB 1.6 MB/s eta 0:00:42   |▎                               | 1.5 MB 2.1 MB/s eta 0:01:30     |█▌                              | 9.1 MB 3.7 MB/s eta 0:00:50                    | 25.5 MB 3.7 MB/s eta 0:00:45     |████▎                           | 25.7 MB 3.7 MB/s eta 0:00:45     |████▎                           | 26.1 MB 3.7 MB/s eta 0:00:45     |████▎                           | 26.2 MB 1.6 MB/s eta 0:01:47     |██████▎                         | 38.1 MB 2.1 MB/s eta 0:01:13     |██████▎                         | 38.2 MB 2.1 MB/s eta 0:01:13     |█████████▏                      | 55.5 MB 2.7 MB/s eta 0:00:51     |████████████                    | 72.1 MB 7.6 MB/s eta 0:00:16     |██████████████▏                 | 85.6 MB 592 kB/s eta 0:03:03     |███████████████▉                | 95.9 MB 2.6 MB/s eta 0:00:38     |████████████████                | 97.0 MB 2.6 MB/s eta 0:00:38     |████████████████                | 97.1 MB 2.6 MB/s eta 0:00:38     |████████████████▏               | 97.7 MB 5.9 MB/s eta 0:00:17/s eta 0:00:17/s eta 0:00:16     |█████████████████               | 103.2 MB 3.5 MB/s eta 0:00:26     |██████████████████▊             | 113.3 MB 6.9 MB/s eta 0:00:12     |██████████████████▊             | 113.6 MB 6.9 MB/s eta 0:00:12     |████████████████████▎           | 122.5 MB 4.0 MB/s eta 0:00:18

# %%
from xgboost import XGBRegressor
xgb_model = XGBRegressor(objective="reg:linear", random_state=42)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [65], in <cell line: 1>()
# ----> 1 import XGBoost
#       2 from xgboost import XGBRegressor
#       3 xgb_model = XGBRegressor(objective="reg:linear", random_state=42)
#
# ModuleNotFoundError: No module named 'XGBoost'

# %%
xgb_model.fit(x_train,y_train)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [66], in <cell line: 1>()
# ----> 1 xgb_model.fit(x_train,y_train)
#
# NameError: name 'xgb_model' is not defined

# %%
xgb_pred = xgb_model.predict(x_test)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [63], in <cell line: 1>()
# ----> 1 xgb_pred = xgb_model.predict(x_test)
#
# NameError: name 'xgb_model' is not defined

# %%
xgb_pred
